# %% [markdown]
# <a href="https://colab.research.google.com/github/GUUlnaz/DZ2/blob/HW_7/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep

base_url = "https://lifehacker.ru/topics/technology/"
pages = 10

article_links = []

for page in range(1, pages + 1):
    if page == 1:
        url = base_url
    else:
        url = f"{base_url}page/{page}/"

    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')


        articles = soup.find_all('article', class_='lh-small-post')

        for article in articles:
            link = article.find('a', class_='lh-small-post__link')['href']
            article_links.append(link)

        print(f"Обработана страница {page}, найдено {len(articles)} материалов")
        sleep(1)

    except Exception as e:
        print(f"Ошибка при обработке страницы {page}: {e}")

print(f"Всего собрано ссылок: {len(article_links)}")

data = []

for link in article_links:
    try:
        response = requests.get(link)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')


        title = soup.find('h1', class_='article-heading').get_text(strip=True)


        content = []
        article_body = soup.find('div', class_='article-content')

        if article_body:
            paragraphs = article_body.find_all('p')
            content = ' '.join(p.get_text(strip=True) for p in paragraphs)
            content = ' '.join(content.split())

        data.append({
            'title': title,
            'content': content,
            'url': link
        })

        print(f"Обработана статья: {title}")
        sleep(1)

    except Exception as e:
        print(f"Ошибка при обработке статьи {link}: {e}")


df = pd.DataFrame(data)


df.to_csv('lifehacker_technology_articles.csv', index=False)
print("Готово! Данные сохранены в lifehacker_technology_articles.csv")


df.head()
# Out:
# Обработана страница 1, найдено 0 материалов
# Ошибка при обработке страницы 2: 404 Client Error: Not Found for url: https://lifehacker.ru/topics/technology/page/2/
# Ошибка при обработке страницы 3: 404 Client Error: Not Found for url: https://lifehacker.ru/topics/technology/page/3/
# Ошибка при обработке страницы 4: 404 Client Error: Not Found for url: https://lifehacker.ru/topics/technology/page/4/
# Ошибка при обработке страницы 5: 404 Client Error: Not Found for url: https://lifehacker.ru/topics/technology/page/5/
# Ошибка при обработке страницы 6: 404 Client Error: Not Found for url: https://lifehacker.ru/topics/technology/page/6/
# Ошибка при обработке страницы 7: 404 Client Error: Not Found for url: https://lifehacker.ru/topics/technology/page/7/
# Ошибка при обработке страницы 8: 404 Client Error: Not Found for url: https://lifehacker.ru/topics/technology/page/8/
# ...
